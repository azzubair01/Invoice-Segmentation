# %% [markdown]
# # 1) Download required files

# %%
# %%cmd
# powershell -Command "Invoke-WebRequest https://raw.githubusercontent.com/hugozanini/object-detection/master/inferenceutils.py -OutFile ./inferenceutils.py"
# Out:
# Microsoft Windows [Version 10.0.19042.746]
# (c) 2020 Microsoft Corporation. All rights reserved.
#
# C:\Users\azzub\OneDrive - Universiti Sains Malaysia\Desktop\DataMicron\RND\myOCR>powershell -Command "Invoke-WebRequest https://raw.githubusercontent.com/hugozanini/object-detection/master/inferenceutils.py -OutFile ./inferenceutils.py"
#
# C:\Users\azzub\OneDrive - Universiti Sains Malaysia\Desktop\DataMicron\RND\myOCR>

# %% [markdown]
# # 2) Extract the saved model

# %%
# %%cmd
# powershell Expand-Archive -Path 'saved_model_frcnn_v1_16022021.zip' -DestinationPath 'saved_model/'
# Out:
# Microsoft Windows [Version 10.0.19042.746]
# (c) 2020 Microsoft Corporation. All rights reserved.
#
# C:\Users\azzub\OneDrive - Universiti Sains Malaysia\Desktop\DataMicron\RND\myOCR>powershell Expand-Archive -Path 'saved_model_frcnn_v1_16022021.zip' -DestinationPath 'saved_model/'
#
# C:\Users\azzub\OneDrive - Universiti Sains Malaysia\Desktop\DataMicron\RND\myOCR>

# %% [markdown]
# # 3) Recall model configurations

# %%
# %%cmd
# move saved_model\content\inference_graph\saved_model\label_map.pbtxt .\label_map.pbtxt
# move saved_model\content\inference_graph\saved_model\test_labels.csv .\test_labels.csv
# mkdir .\dataset\test
# copy saved_model\content\inference_graph\saved_model\test\* .\dataset\test
# Out:
# Microsoft Windows [Version 10.0.19042.746]
# (c) 2020 Microsoft Corporation. All rights reserved.
#
# C:\Users\azzub\OneDrive - Universiti Sains Malaysia\Desktop\DataMicron\RND\myOCR>move saved_model\content\inference_graph\saved_model\label_map.pbtxt .\label_map.pbtxt
#         1 file(s) moved.
#
# C:\Users\azzub\OneDrive - Universiti Sains Malaysia\Desktop\DataMicron\RND\myOCR>move saved_model\content\inference_graph\saved_model\test_labels.csv .\test_labels.csv
#         1 file(s) moved.
#
# C:\Users\azzub\OneDrive - Universiti Sains Malaysia\Desktop\DataMicron\RND\myOCR>mkdir .\dataset\test
#
# C:\Users\azzub\OneDrive - Universiti Sains Malaysia\Desktop\DataMicron\RND\myOCR>copy saved_model\content\inference_graph\saved_model\test\* .\dataset\test
# saved_model\content\inference_graph\saved_model\test\Invoice_103_affine_translation.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_107.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_109.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_115.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_115_gaussianblur.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_120.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_121_brightness.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_124_gaussianblur.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_126_affine_translation.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_127.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_12_gaussianblur.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_136_affine_translation.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_136_gaussianblur.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_140_horizontallyflip.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_142_horizontallyflip.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_143_horizontallyflip.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_146_affine_translation.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_148_brightness.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_154.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_156.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_162.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_162_brightness.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_165_gaussianblur.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_166_affine_translation.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_166_horizontallyflip.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_168.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_176_affine_translation.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_178_gaussianblur.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_18.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_182_horizontallyflip.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_187_horizontallyflip.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_193.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_19_brightness.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_40_gaussianblur.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_47_horizontallyflip.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_4_brightness.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_56.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_57_horizontallyflip.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_61_horizontallyflip.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_63.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_63_affine_translation.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_72.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_76_affine_translation.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_7_gaussianblur.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_83_affine_translation.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_87_brightness.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_88_horizontallyflip.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_92_gaussianblur.jpg
# saved_model\content\inference_graph\saved_model\test\Invoice_98_horizontallyflip.jpg
#        49 file(s) copied.
#
# C:\Users\azzub\OneDrive - Universiti Sains Malaysia\Desktop\DataMicron\RND\myOCR>

# %%
output_directory = 'inference_graph'
labelmap_path = 'label_map.pbtxt'

import tensorflow as tf
from object_detection.utils import label_map_util
category_index = label_map_util.create_category_index_from_labelmap(labelmap_path, use_display_name=True)
tf.keras.backend.clear_session()
model = tf.saved_model.load(f'saved_model/content/inference_graph/saved_model')

# %% [markdown]
# # 4) Select images to be tested

# %%
import pandas as pd
test = pd.read_csv('test_labels.csv')
#Getting 3 random images to test
images = list(test.sample(n=3)['filename'])
images
# Out:
# ['Invoice_56.jpg', 'Invoice_56.jpg', 'Invoice_121_brightness.jpg']

# %%
from pdf2image import convert_from_path
pages = convert_from_path('Adatum6.pdf')

# !mkdir dataset

for page in pages:
    page.save('dataset/adatum_test.jpg', 'JPEG')
# Out:
# A subdirectory or file dataset already exists.

# %% [markdown]
# # 5) Test the detection model

# %%
from inferenceutils import *

image_test = 'adatum_test.jpg'
image_np = load_image_into_numpy_array('dataset/'+image_test)
output_dict = run_inference_for_single_image(model, image_np)
vis_util.visualize_boxes_and_labels_on_image_array(
    image_np,
    output_dict['detection_boxes'],
    output_dict['detection_classes'],
    output_dict['detection_scores'],
    category_index,
    instance_masks=output_dict.get('detection_masks_reframed', None),
    use_normalized_coordinates=True,
    line_thickness=8)
display(Image.fromarray(image_np))
# Out:
# <PIL.Image.Image image mode=RGB size=1700x2200 at 0x1A3172CF488>

# %%
# for multiple images, use this code
for image_name in images:
    image_np = load_image_into_numpy_array('dataset/test/' + image_name)
    output_dict = run_inference_for_single_image(model, image_np)
    vis_util.visualize_boxes_and_labels_on_image_array(
        image_np,
        output_dict['detection_boxes'],
        output_dict['detection_classes'],
        output_dict['detection_scores'],
        category_index,
        instance_masks=output_dict.get('detection_masks_reframed', None),
        use_normalized_coordinates=True,
        line_thickness=3)
    display(Image.fromarray(image_np))
# Out:
# <PIL.Image.Image image mode=RGB size=600x600 at 0x1A328966288>
# <PIL.Image.Image image mode=RGB size=600x600 at 0x1A31A388348>
# <PIL.Image.Image image mode=RGB size=600x600 at 0x1A3260F7C08>

# %% [markdown]
# # 6) Export the predicted coordinates as CSV file

# %%
# for single image, use this code

import pandas as pd
rows = []

final_dataframe = pd.DataFrame(columns=['Image','Score','Class','Ymin','Xmin','Ymax','Xmax'])
image_np = load_image_into_numpy_array('dataset/'+image_test)
output_dict = run_inference_for_single_image(model, image_np)
# store boxes in dataframe!
cut_off_scores = len(list(filter(lambda x: x >= 0.1, output_dict['detection_scores'])))
for j in range(cut_off_scores):
    name = image_test
    scores = output_dict['detection_scores'][j]
    classes = output_dict['detection_classes'][j]
    for i in range(1,len(category_index)+1):
        if output_dict['detection_classes'][j] == category_index[i]['id']:
            classes = category_index[i]['name']
    ymin = output_dict['detection_boxes'][j][0]
    xmin = output_dict['detection_boxes'][j][1]
    ymax = output_dict['detection_boxes'][j][2]
    xmax = output_dict['detection_boxes'][j][3]
    row = list([name, scores, classes, ymin, xmin, ymax, xmax])
    rows.append(row)

final_df = pd.DataFrame(rows, columns = ['Image', 'Scores', 'Classes', 'ymin', 'xmin', 'ymax', 'xmax'])
final_df.to_csv('dataset/predicted_coordinates.csv', index = False)
final_df
# Out:
#              Image    Scores    Classes      ymin      xmin      ymax  \
# 0  adatum_test.jpg  0.999299  paragraph  0.119367  0.649661  0.227688
# 1  adatum_test.jpg  0.998966  paragraph  0.126477  0.065920  0.180108
# 2  adatum_test.jpg  0.996288  paragraph  0.047687  0.071766  0.087613
# 3  adatum_test.jpg  0.995500  paragraph  0.120276  0.344557  0.181856
# 4  adatum_test.jpg  0.988213      table  0.393024  0.062122  0.642185
# 5  adatum_test.jpg  0.926101  paragraph  0.234364  0.067633  0.325944
# 6  adatum_test.jpg  0.725307  paragraph  0.810896  0.062161  0.890081
#
#        xmax
# 0  0.873520
# 1  0.235504
# 2  0.250300
# 3  0.511097
# 4  0.905454
# 5  0.208898
# 6  0.253218

# %%
rows = []

final_dataframe = pd.DataFrame(columns=['Image','Score','Class','Ymin','Xmin','Ymax','Xmax'])
for image_name in images:
  
    image_np = load_image_into_numpy_array('dataset/test/' + image_name)
    output_dict = run_inference_for_single_image(model, image_np)

    # store boxes in dataframe!
    cut_off_scores = len(list(filter(lambda x: x >= 0.1, output_dict['detection_scores'])))

    for j in range(cut_off_scores):
        name = image_name
        scores = output_dict['detection_scores'][j]
        classes = output_dict['detection_classes'][j]
        for i in range(1,len(category_index)+1):
            if output_dict['detection_classes'][j] == category_index[i]['id']:
                classes = category_index[i]['name']
        ymin = output_dict['detection_boxes'][j][0]
        xmin = output_dict['detection_boxes'][j][1]
        ymax = output_dict['detection_boxes'][j][2]
        xmax = output_dict['detection_boxes'][j][3]

        row = list([name, scores, classes, ymin, xmin, ymax, xmax])
        rows.append(row)

final_df = pd.DataFrame(rows, columns = ['Image', 'Scores', 'Classes', 'ymin', 'xmin', 'ymax', 'xmax'])
final_df.to_csv('predicted_coordinates.csv', index = False)
final_df
# Out:
#                          Image    Scores    Classes      ymin      xmin  \
# 0               Invoice_56.jpg  0.999767      table  0.459763  0.104882
# 1               Invoice_56.jpg  0.999418  paragraph  0.727458  0.587551
# 2               Invoice_56.jpg  0.999202  paragraph  0.211822  0.113454
# 3               Invoice_56.jpg  0.999133  paragraph  0.828418  0.442052
# 4               Invoice_56.jpg  0.999036  paragraph  0.185277  0.523648
# 5               Invoice_56.jpg  0.998946  paragraph  0.827169  0.105138
# 6               Invoice_56.jpg  0.998818  paragraph  0.089547  0.109721
# 7               Invoice_56.jpg  0.998565  paragraph  0.077729  0.701466
# 8               Invoice_56.jpg  0.998056  paragraph  0.832623  0.760376
# 9               Invoice_56.jpg  0.993396  paragraph  0.122702  0.117178
# 10              Invoice_56.jpg  0.990663  paragraph  0.387370  0.112021
# 11              Invoice_56.jpg  0.870286  paragraph  0.418556  0.522099
# 12              Invoice_56.jpg  0.309440      table  0.464982  0.503594
# 13              Invoice_56.jpg  0.999767      table  0.459763  0.104882
# 14              Invoice_56.jpg  0.999418  paragraph  0.727458  0.587551
# 15              Invoice_56.jpg  0.999202  paragraph  0.211822  0.113454
# 16              Invoice_56.jpg  0.999133  paragraph  0.828418  0.442052
# 17              Invoice_56.jpg  0.999036  paragraph  0.185277  0.523648
# 18              Invoice_56.jpg  0.998946  paragraph  0.827169  0.105138
# 19              Invoice_56.jpg  0.998818  paragraph  0.089547  0.109721
# 20              Invoice_56.jpg  0.998565  paragraph  0.077729  0.701466
# 21              Invoice_56.jpg  0.998056  paragraph  0.832623  0.760376
# 22              Invoice_56.jpg  0.993396  paragraph  0.122702  0.117178
# 23              Invoice_56.jpg  0.990663  paragraph  0.387370  0.112021
# 24              Invoice_56.jpg  0.870286  paragraph  0.418556  0.522099
# 25              Invoice_56.jpg  0.309440      table  0.464982  0.503594
# 26  Invoice_121_brightness.jpg  0.999773  paragraph  0.048129  0.710122
# 27  Invoice_121_brightness.jpg  0.999715  paragraph  0.017307  0.052888
# 28  Invoice_121_brightness.jpg  0.999645  paragraph  0.181842  0.641353
# 29  Invoice_121_brightness.jpg  0.998997  paragraph  0.179312  0.041726
# 30  Invoice_121_brightness.jpg  0.998829      table  0.511025  0.019908
# 31  Invoice_121_brightness.jpg  0.998583      table  0.364419  0.039372
# 32  Invoice_121_brightness.jpg  0.997965  paragraph  0.829881  0.058358
# 33  Invoice_121_brightness.jpg  0.995078  paragraph  0.856014  0.505866
# 34  Invoice_121_brightness.jpg  0.427960      table  0.356438  0.046186
#
#         ymax      xmax
# 0   0.705264  0.940243
# 1   0.795573  0.961320
# 2   0.309980  0.284516
# 3   0.916054  0.601986
# 4   0.327266  0.854624
# 5   0.937046  0.274298
# 6   0.121622  0.353655
# 7   0.121794  0.894064
# 8   0.906350  0.895663
# 9   0.200893  0.210835
# 10  0.422264  0.318838
# 11  0.469664  0.911116
# 12  0.705020  0.920368
# 13  0.705264  0.940243
# 14  0.795573  0.961320
# 15  0.309980  0.284516
# 16  0.916054  0.601986
# 17  0.327266  0.854624
# 18  0.937046  0.274298
# 19  0.121622  0.353655
# 20  0.121794  0.894064
# 21  0.906350  0.895663
# 22  0.200893  0.210835
# 23  0.422264  0.318838
# 24  0.469664  0.911116
# 25  0.705020  0.920368
# 26  0.129643  0.950318
# 27  0.133132  0.399855
# 28  0.286979  0.945554
# 29  0.288063  0.536241
# 30  0.682243  0.935309
# 31  0.502631  0.932039
# 32  0.942726  0.310628
# 33  0.943698  0.764292
# 34  0.666861  0.949026
